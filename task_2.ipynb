# %% [markdown]
# **Считываем данные из файла train.csv с помощью библиотеки pandas**

# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\Gleb\Desktop\Итмо\Основы Питона\train.csv').sort_values(by = 'Age', ascending = False)
df.head(10)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 745          746         0       1          Crosby, Capt. Edward Gifford
# 672          673         0       2           Mitchell, Mr. Henry Michael
# 33            34         0       2                 Wheadon, Mr. Edward H
# 456          457         0       1             Millet, Mr. Francis Davis
# 54            55         0       1        Ostby, Mr. Engelhart Cornelius
#
#       Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 630  male  80.0      0      0       27042  30.0000   A23        S
# 851  male  74.0      0      0      347060   7.7750   NaN        S
# 493  male  71.0      0      0    PC 17609  49.5042   NaN        C
# 96   male  71.0      0      0    PC 17754  34.6542    A5        C
# 116  male  70.5      0      0      370369   7.7500   NaN        Q
# 745  male  70.0      1      1   WE/P 5735  71.0000   B22        S
# 672  male  70.0      0      0  C.A. 24580  10.5000   NaN        S
# 33   male  66.0      0      0  C.A. 24579  10.5000   NaN        S
# 456  male  65.0      0      0       13509  26.5500   E38        S
# 54   male  65.0      0      1      113509  61.9792   B30        C

# %% [markdown]
# **Основное инфо**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 891 entries, 630 to 888
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 90.5+ KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# **Процент выживаемости по классам пассажиров**

# %%
unique = (df['Pclass'].unique())
unique
# Out:
# array([1, 3, 2])

# %%
survival_by_class = df.groupby('Pclass')['Survived'].mean() * 100
survival_by_class
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %% [markdown]
# **популярное мужское и самое популярное женское имя на корабле**

# %%
# имя в скобках
name_in_brackets = df['Name'].str.extract(r'\(([^ ]+)')

# имя после титула
name_after_title = df['Name'].str.extract(r',\s*[^\.]+\.\s*([A-Za-z]+)')

# итоговое имя
df['FirstName'] = name_in_brackets[0].fillna(name_after_title[0])

male_name = df[df['Sex'] == 'male']['FirstName'].value_counts().idxmax()
female_name = df[df['Sex'] == 'female']['FirstName'].value_counts().idxmax()

print('Самое популярное мужское имя:', male_name)
print('Самое популярное женское имя:', female_name)
# Out:
# Самое популярное мужское имя: William
# Самое популярное женское имя: Anna

# %% [markdown]
# **популярное мужское и самое популярное женское имя на корабле в каждом классе**

# %%
for pclass in sorted(df['Pclass'].unique()):

    subset = df[df['Pclass'] == pclass]

    male_name = subset[subset['Sex'] == 'male']['FirstName'].value_counts().idxmax()
    female_name = subset[subset['Sex'] == 'female']['FirstName'].value_counts().idxmax()

    print(f'Класс {pclass}')
    print(f'Мужское имя: {male_name}')
    print(f'Женское имя: {female_name}')
    print()
# Out:
# Класс 1
# Мужское имя: William
# Женское имя: Elizabeth
#
# Класс 2
# Мужское имя: William
# Женское имя: Elizabeth
#
# Класс 3
# Мужское имя: William
# Женское имя: Anna

# %% [markdown]
# **Пассажиры старше 44 лет**

# %%
df[df['Age'] > 44]
# Out:
#      PassengerId  Survived  Pclass  \
# 630          631         1       1
# 851          852         0       3
# 493          494         0       1
# 96            97         0       1
# 116          117         0       3
# ..           ...       ...     ...
# 440          441         1       2
# 706          707         1       2
# 856          857         1       1
# 62            63         0       1
# 187          188         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 630           Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 851                            Svensson, Mr. Johan    male  74.0      0
# 493                        Artagaveytia, Mr. Ramon    male  71.0      0
# 96                       Goldschmidt, Mr. George B    male  71.0      0
# 116                           Connors, Mr. Patrick    male  70.5      0
# ..                                             ...     ...   ...    ...
# 440    Hart, Mrs. Benjamin (Esther Ada Bloomfield)  female  45.0      1
# 706                  Kelly, Mrs. Florence "Fannie"  female  45.0      0
# 856     Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 62                     Harris, Mr. Henry Birkhardt    male  45.0      1
# 187  Romaine, Mr. Charles Hallace ("Mr C Rolmane")    male  45.0      0
#
#      Parch        Ticket      Fare Cabin Embarked FirstName
# 630      0         27042   30.0000   A23        S  Algernon
# 851      0        347060    7.7750   NaN        S     Johan
# 493      0      PC 17609   49.5042   NaN        C     Ramon
# 96       0      PC 17754   34.6542    A5        C    George
# 116      0        370369    7.7500   NaN        Q   Patrick
# ..     ...           ...       ...   ...      ...       ...
# 440      1  F.C.C. 13529   26.2500   NaN        S    Esther
# 706      0        223596   13.5000   NaN        S  Florence
# 856      1         36928  164.8667   NaN        S      Mary
# 62       0         36973   83.4750   C83        S     Henry
# 187      0        111428   26.5500   NaN        S       "Mr
#
# [115 rows x 13 columns]

# %% [markdown]
# **Мужчины младше 44**

# %%
df[(df['Age'] < 44) & (df['Sex'] == 'male')]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 668          669         0       3                           Cook, Mr. Jacob
# 314          315         0       2                        Hart, Mr. Benjamin
# 818          819         0       3          Holm, Mr. John Fredrik Alexander
# 699          700         0       3  Humblen, Mr. Adolf Mathias Nicolai Olsen
# 349          350         0       3                          Dimic, Mr. Jovan
# ..           ...       ...     ...                                       ...
# 305          306         1       1            Allison, Master. Hudson Trevor
# 78            79         1       2             Caldwell, Master. Alden Gates
# 831          832         1       2           Richards, Master. George Sibley
# 755          756         1       2                 Hamalainen, Master. Viljo
# 803          804         1       3           Thomas, Master. Assad Alexander
#
#       Sex    Age  SibSp  Parch        Ticket      Fare    Cabin Embarked  \
# 668  male  43.00      0      0      A/5 3536    8.0500      NaN        S
# 314  male  43.00      1      1  F.C.C. 13529   26.2500      NaN        S
# 818  male  43.00      0      0        C 7075    6.4500      NaN        S
# 699  male  42.00      0      0        348121    7.6500    F G63        S
# 349  male  42.00      0      0        315088    8.6625      NaN        S
# ..    ...    ...    ...    ...           ...       ...      ...      ...
# 305  male   0.92      1      2        113781  151.5500  C22 C26        S
# 78   male   0.83      0      2        248738   29.0000      NaN        S
# 831  male   0.83      1      1         29106   18.7500      NaN        S
# 755  male   0.67      1      1        250649   14.5000      NaN        S
# 803  male   0.42      0      1          2625    8.5167      NaN        C
#
#     FirstName
# 668     Jacob
# 314  Benjamin
# 818      John
# 699     Adolf
# 349     Jovan
# ..        ...
# 305    Hudson
# 78      Alden
# 831    George
# 755     Viljo
# 803     Assad
#
# [368 rows x 13 columns]

# %% [markdown]
# **Кол-во n-местных кабин**

# %%
cabins = df['Cabin'].dropna()
cabins_count = cabins.str.split().apply(len).value_counts()
cabins_count
# Out:
# Cabin
# 1    180
# 2     16
# 3      6
# 4      2
# Name: count, dtype: int64

# %% [markdown]
# **Пассажиры без родственников на борту**

# %%
no_relatives = df[(df['SibSp'] == 0) & (df['Parch'] == 0)]
len(no_relatives)
# Out:
# 537
